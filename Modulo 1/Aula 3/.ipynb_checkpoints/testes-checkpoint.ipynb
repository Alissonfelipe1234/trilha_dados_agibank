# %%
import sys

a = [1, 2, 3, 4, 5]
b = (1, 2, 3, 4, 5)

print(f"List size: {sys.getsizeof(a)} bytes")
print(f"Tuple size: {sys.getsizeof(b)} bytes")


texto = "hello world00 00 "
print(f"Tuple size: {sys.getsizeof(texto)} bytes")
# Out:
# List size: 104 bytes
# Tuple size: 80 bytes
# Tuple size: 58 bytes

# %%
# divisao int
100 % 21
# Out:
# 16

# %%
sys.getsizeof("mensagem de texto")
# Out:
# 58

# %%
sys.getsizeof("mensagem de texto ")
# Out:
# 59

# %%
padronizar_texto = "Aula 3 trilha Python"
padronizar_texto
# Out:
# 'Aula 3 trilha Python'

# %%
padronizar_texto.upper()
# Out:
# 'AULA 3 TRILHA PYTHON'

# %%
padronizar_texto.lower()
# Out:
# 'aula 3 trilha python'

# %%
padronizar_texto.capitalize()
# Out:
# 'Aula 3 trilha python'

# %%
padronizar_texto[0]
# Out:
# 'A'
