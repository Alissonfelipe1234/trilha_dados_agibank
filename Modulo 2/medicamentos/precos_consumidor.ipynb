# %%
import pandas as pd
import numpy as np

# %%
medicamentos = pd.read_csv('xls_conformidade_site_20251208_170820642.xlsx')
medicamentos.head()
# Out:
#                          Secretaria Executiva - CMED Unnamed: 1 Unnamed: 2  \
# 0  LISTA DE PREÇOS DE MEDICAMENTOS - PREÇOS FÁBRI...        NaN        NaN
# 1                  Publicada em 08/12/2025 18h30min.        NaN        NaN
# 2                                                NaN        NaN        NaN
# 3  Esta lista apresenta os preços dos medicamento...        NaN        NaN
# 4                                                NaN        NaN        NaN
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#   Unnamed: 9  ... Unnamed: 64 Unnamed: 65 Unnamed: 66 Unnamed: 67 Unnamed: 68  \
# 0        NaN  ...         NaN         NaN         NaN         NaN         NaN
# 1        NaN  ...         NaN         NaN         NaN         NaN         NaN
# 2        NaN  ...         NaN         NaN         NaN         NaN         NaN
# 3        NaN  ...         NaN         NaN         NaN         NaN         NaN
# 4        NaN  ...         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 69 Unnamed: 70 Unnamed: 71 Unnamed: 72 Unnamed: 73
# 0         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN
#
# [5 rows x 74 columns]

# %%
medicamentos = pd.read_excel('xls_conformidade_site_20251208_170820642.xlsx', skiprows=41)
medicamentos.head()
# Out:
#                                SUBSTÂNCIA                CNPJ  \
# 0  21-ACETATO DE DEXAMETASONA;CLOTRIMAZOL  18.459.628/0001-15
# 1                              ABATACEPTE  56.998.982/0001-07
# 2                              ABATACEPTE  56.998.982/0001-07
# 3                            ABEMACICLIBE  43.940.618/0001-44
# 4                            ABEMACICLIBE  43.940.618/0001-44
#
#                               LABORATÓRIO     CÓDIGO GGREM       REGISTRO  \
# 0                              BAYER S.A.  538912020009303  1705600230032
# 1  BRISTOL-MYERS SQUIBB FARMACÊUTICA LTDA  505107701157215  1018003900019
# 2  BRISTOL-MYERS SQUIBB FARMACÊUTICA LTDA  505113100020505  1018003900078
# 3                ELI LILLY DO BRASIL LTDA  507619060021902  1126001990018
# 4                ELI LILLY DO BRASIL LTDA  507619060022102  1126001990034
#
#            EAN 1       EAN 2       EAN 3     PRODUTO  \
# 0  7891106000956      -           -       BAYCUTEN N
# 1  7896016806469      -           -          ORENCIA
# 2  7896016808197      -           -          ORENCIA
# 3  7896382708442      -           -        VERZENIOS
# 4  7896382708466      -           -        VERZENIOS
#
#                                         APRESENTAÇÃO  ... PMC 23 %  ALC  \
# 0     10 MG/G + 0,443 MG/G CREM DERM CT BG AL X 40 G  ...         48,08
# 1   250 MG PO LIOF SOL INJ CT 1 FA + SER DESCARTÁVEL  ...           NaN
# 2  125 MG/ML SOL INJ SC CT 4 SER PREENC VD TRANS ...  ...      11828,90
# 3                     50 MG COM REV CT BL AL AL X 30  ...       5001,73
# 4                    100 MG COM REV CT BL AL AL X 30  ...      10003,41
#
#   RESTRIÇÃO HOSPITALAR  CAP CONFAZ 87 ICMS 0% ANÁLISE RECURSAL  \
# 0                  Não  Não       Não     Não              NaN
# 1                  Sim  Sim       Não     Não              NaN
# 2                  Não  Sim       Sim     Não              NaN
# 3                  Não  Não       Não     Não              NaN
# 4                  Não  Não       Não     Não              NaN
#
#   LISTA DE CONCESSÃO DE CRÉDITO TRIBUTÁRIO (PIS/COFINS) COMERCIALIZAÇÃO 2024  \
# 0                                           Negativa                     Sim
# 1                                           Positiva                     Sim
# 2                                           Positiva                     Sim
# 3                                           Negativa                     Sim
# 4                                           Negativa                     Sim
#
#             TARJA DESTINAÇÃO COMERCIAL
# 0          - (*)                    NaN
# 1  Tarja Vermelha                   NaN
# 2          - (*)                    NaN
# 3  Tarja Vermelha                   NaN
# 4  Tarja Vermelha                   NaN
#
# [5 rows x 74 columns]

# %%
medicamentos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26775 entries, 0 to 26774
# Data columns (total 74 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   SUBSTÂNCIA                                             26775 non-null  object
#  1   CNPJ                                                   26775 non-null  object
#  2   LABORATÓRIO                                            26775 non-null  object
#  3   CÓDIGO GGREM                                           26775 non-null  object
#  4   REGISTRO                                               26775 non-null  int64
#  5   EAN 1                                                  26775 non-null  object
#  6   EAN 2                                                  26775 non-null  object
#  7   EAN 3                                                  26775 non-null  object
#  8   PRODUTO                                                26775 non-null  object
#  9   APRESENTAÇÃO                                           26775 non-null  object
#  10  CLASSE TERAPÊUTICA                                     26775 non-null  object
#  11  TIPO DE PRODUTO (STATUS DO PRODUTO)                    26775 non-null  object
#  12  REGIME DE PREÇO                                        26775 non-null  object
#  13  PF Sem Impostos                                        26775 non-null  object
#  14  PF 0%                                                  26775 non-null  object
#  15  PF 12 %                                                26775 non-null  object
#  16  PF 12 %  ALC                                           26775 non-null  object
#  17  PF 17 %                                                26775 non-null  object
#  18  PF 17 %  ALC                                           26775 non-null  object
#  19  PF 17,5 %                                              26775 non-null  object
#  20  PF 17,5 %  ALC                                         26775 non-null  object
#  21  PF 18 %                                                26775 non-null  object
#  22  PF 18 %  ALC                                           26775 non-null  object
#  23  PF 19 %                                                26775 non-null  object
#  24  PF 19 %  ALC                                           26775 non-null  object
#  25  PF 19,5 %                                              26775 non-null  object
#  26  PF 19,5 %  ALC                                         26775 non-null  object
#  27  PF 20 %                                                26775 non-null  object
#  28  PF 20 %  ALC                                           26775 non-null  object
#  29  PF 20,5 %                                              26775 non-null  object
#  30  PF 20,5 %  ALC                                         26775 non-null  object
#  31  PF 21 %                                                26775 non-null  object
#  32  PF 21 %  ALC                                           26775 non-null  object
#  33  PF 22 %                                                26775 non-null  object
#  34  PF 22 %  ALC                                           26775 non-null  object
#  35  PF 22,5 %                                              26775 non-null  object
#  36  PF 22,5 %  ALC                                         26775 non-null  object
#  37  PF 23 %                                                26775 non-null  object
#  38  PF 23 %  ALC                                           26775 non-null  object
#  39  PMC Sem Impostos                                       22719 non-null  object
#  40  PMC 0 %                                                22719 non-null  object
#  41  PMC 12 %                                               22719 non-null  object
#  42  PMC 12 %  ALC                                          22719 non-null  object
#  43  PMC 17 %                                               22719 non-null  object
#  44  PMC 17 %  ALC                                          22719 non-null  object
#  45  PMC 17,5 %                                             22719 non-null  object
#  46  PMC 17,5 %  ALC                                        22719 non-null  object
#  47  PMC 18 %                                               22719 non-null  object
#  48  PMC 18 %  ALC                                          22719 non-null  object
#  49  PMC 19 %                                               22719 non-null  object
#  50  PMC 19 %  ALC                                          22719 non-null  object
#  51  PMC 19,5 %                                             22719 non-null  object
#  52  PMC 19,5 %  ALC                                        22719 non-null  object
#  53  PMC 20 %                                               22719 non-null  object
#  54  PMC 20 %  ALC                                          22719 non-null  object
#  55  PMC 20,5 %                                             22719 non-null  object
#  56  PMC 20,5 %  ALC                                        22719 non-null  object
#  57  PMC 21 %                                               22719 non-null  object
#  58  PMC 21 %  ALC                                          22719 non-null  object
#  59  PMC 22 %                                               22719 non-null  object
#  60  PMC 22 %  ALC                                          22719 non-null  object
#  61  PMC 22,5 %                                             22719 non-null  object
#  62  PMC 22,5 %  ALC                                        22719 non-null  object
#  63  PMC 23 %                                               22719 non-null  object
#  64  PMC 23 %  ALC                                          22719 non-null  object
#  65  RESTRIÇÃO HOSPITALAR                                   26775 non-null  object
#  66  CAP                                                    26775 non-null  object
#  67  CONFAZ 87                                              26775 non-null  object
#  68  ICMS 0%                                                26775 non-null  object
#  69  ANÁLISE RECURSAL                                       129 non-null    object
#  70  LISTA DE CONCESSÃO DE CRÉDITO TRIBUTÁRIO (PIS/COFINS)  26775 non-null  object
#  71  COMERCIALIZAÇÃO 2024                                   26775 non-null  object
#  72  TARJA                                                  26775 non-null  object
#  73  DESTINAÇÃO COMERCIAL                                   0 non-null      float64
# dtypes: float64(1), int64(1), object(72)
# memory usage: 15.1+ MB

# %%
medicamentos.count()
# Out:
# SUBSTÂNCIA                                               26775
# CNPJ                                                     26775
# LABORATÓRIO                                              26775
# CÓDIGO GGREM                                             26775
# REGISTRO                                                 26775
#                                                          ...
# ANÁLISE RECURSAL                                           129
# LISTA DE CONCESSÃO DE CRÉDITO TRIBUTÁRIO (PIS/COFINS)    26775
# COMERCIALIZAÇÃO 2024                                     26775
# TARJA                                                    26775
# DESTINAÇÃO COMERCIAL                                         0
# Length: 74, dtype: int64

# %%
medicamentos.columns
# Out:
# Index(['SUBSTÂNCIA', 'CNPJ', 'LABORATÓRIO', 'CÓDIGO GGREM', 'REGISTRO',
#        'EAN 1', 'EAN 2', 'EAN 3', 'PRODUTO', 'APRESENTAÇÃO',
#        'CLASSE TERAPÊUTICA', 'TIPO DE PRODUTO (STATUS DO PRODUTO)',
#        'REGIME DE PREÇO', 'PF Sem Impostos', 'PF 0%', 'PF 12 %',
#        'PF 12 %  ALC', 'PF 17 %', 'PF 17 %  ALC', 'PF 17,5 %',
#        'PF 17,5 %  ALC', 'PF 18 %', 'PF 18 %  ALC', 'PF 19 %', 'PF 19 %  ALC',
#        'PF 19,5 %', 'PF 19,5 %  ALC', 'PF 20 %', 'PF 20 %  ALC', 'PF 20,5 %',
#        'PF 20,5 %  ALC', 'PF 21 %', 'PF 21 %  ALC', 'PF 22 %', 'PF 22 %  ALC',
#        'PF 22,5 %', 'PF 22,5 %  ALC', 'PF 23 %', 'PF 23 %  ALC',
#        'PMC Sem Impostos', 'PMC 0 %', 'PMC 12 %', 'PMC 12 %  ALC', 'PMC 17 %',
#        'PMC 17 %  ALC', 'PMC 17,5 %', 'PMC 17,5 %  ALC', 'PMC 18 %',
#        'PMC 18 %  ALC', 'PMC 19 %', 'PMC 19 %  ALC', 'PMC 19,5 %',
#        'PMC 19,5 %  ALC', 'PMC 20 %', 'PMC 20 %  ALC', 'PMC 20,5 %',
#        'PMC 20,5 %  ALC', 'PMC 21 %', 'PMC 21 %  ALC', 'PMC 22 %',
#        'PMC 22 %  ALC', 'PMC 22,5 %', 'PMC 22,5 %  ALC', 'PMC 23 %',
#        'PMC 23 %  ALC', 'RESTRIÇÃO HOSPITALAR', 'CAP', 'CONFAZ 87', 'ICMS 0%',
#        'ANÁLISE RECURSAL',
#        'LISTA DE CONCESSÃO DE CRÉDITO TRIBUTÁRIO (PIS/COFINS)',
#        'COMERCIALIZAÇÃO 2024', 'TARJA', 'DESTINAÇÃO COMERCIAL '],
#       dtype='object')

# %%
medicamentos['TIPO DE PRODUTO (STATUS DO PRODUTO)'].unique()
# Out:
# array(['Novo', 'Biológico', 'Similar', 'Genérico', 'Específico',
#        'Fitoterápico', '    -     ', 'Produto de Terapia Avançada',
#        'Radiofármaco'], dtype=object)

# %%
medicamentos['REGIME DE PREÇO'].unique()
# Out:
# array(['Regulado', 'Liberado'], dtype=object)

# %%
medicamentos.loc[medicamentos['TIPO DE PRODUTO (STATUS DO PRODUTO)'] == '    -     ', :]
# Out:
#                                               SUBSTÂNCIA                CNPJ  \
# 865                               ALFACORIOGONADOTROPINA  33.069.212/0001-84
# 866                               ALFACORIOGONADOTROPINA  33.069.212/0001-84
# 948                                      ALFAFOLITROPINA  33.069.212/0001-84
# 949                                      ALFAFOLITROPINA  33.069.212/0001-84
# 950                                      ALFAFOLITROPINA  33.069.212/0001-84
# 1366                ANTÍGENO DE SUPERFÍCIE DA HEPATITE B  10.588.595/0010-92
# 2512                                  BETAINTERFERONA 1A  33.069.212/0001-84
# 2513                                  BETAINTERFERONA 1A  33.069.212/0001-84
# 3496                                          CALCITRIOL  45.992.062/0001-65
# 3497                                          CALCITRIOL  45.992.062/0001-65
# 3499                                          CALCITRIOL  15.800.545/0001-50
# 3838                              CARBOXIMALTOSE FERRICA  53.359.824/0001-19
# 7363                            CLORIDRATO DE FLUOXETINA  00.923.140/0001-31
# 7364                            CLORIDRATO DE FLUOXETINA  00.923.140/0001-31
# 7365                            CLORIDRATO DE FLUOXETINA  00.923.140/0001-31
# 7366                            CLORIDRATO DE FLUOXETINA  00.923.140/0001-31
# 7367                            CLORIDRATO DE FLUOXETINA  00.923.140/0001-31
# 8723                            CLORIDRATO DE RANITIDINA  45.992.062/0001-65
# 8724                            CLORIDRATO DE RANITIDINA  45.992.062/0001-65
# 9600                                          COLAGENASE  56.998.701/0001-16
# 9601                                          COLAGENASE  56.998.701/0001-16
# 9602                                          COLAGENASE  56.998.701/0001-16
# 12241                                 ENOXAPARINA SÓDICA  11.643.096/0001-22
# 12242                                 ENOXAPARINA SÓDICA  11.643.096/0001-22
# 12243                                 ENOXAPARINA SÓDICA  11.643.096/0001-22
# 12244                                 ENOXAPARINA SÓDICA  11.643.096/0001-22
# 12245                                 ENOXAPARINA SÓDICA  11.643.096/0001-22
# 12246                                 ENOXAPARINA SÓDICA  11.643.096/0001-22
# 12247                                 ENOXAPARINA SÓDICA  11.643.096/0001-22
# 12248                                 ENOXAPARINA SÓDICA  11.643.096/0001-22
# 12249                                 ENOXAPARINA SÓDICA  11.643.096/0001-22
# 12250                                 ENOXAPARINA SÓDICA  11.643.096/0001-22
# 12251                                 ENOXAPARINA SÓDICA  11.643.096/0001-22
# 12252                                 ENOXAPARINA SÓDICA  11.643.096/0001-22
# 16363                                    INSULINA HUMANA  13.078.518/0001-90
# 16364                                    INSULINA HUMANA  13.078.518/0001-90
# 18816                                        METOTREXATO  46.070.868/0036-99
# 19533                                       NIPOCALIMABE  51.780.468/0001-87
# 19534                                       NIPOCALIMABE  51.780.468/0001-87
# 21301                                        PARACETAMOL  61.082.426/0002-07
# 21738  POLISSACARÍDEO CAPSULAR DE STREPTOCOCCUS PNEUM...  61.072.393/0001-33
# 21739  POLISSACARÍDEO CAPSULAR DE STREPTOCOCCUS PNEUM...  61.072.393/0001-33
# 21750  POLISSACARÍDEO DE HAEMOPHILUS INFLUENZAE TIPO ...  10.588.595/0010-92
# 23890                                        SOMATROPINA  02.433.631/0001-20
# 24180                          SUCCINATO DE SUMATRIPTANA  33.247.743/0001-10
# 24181                          SUCCINATO DE SUMATRIPTANA  33.247.743/0001-10
# 25481  TOXÓIDE PERTUSSIS;FÍMBRIAS;TOXÓIDE DIFTÉRICO;P...  10.588.595/0010-92
# 25484  TOXÓIDE PERTUSSIS;POLIOVÍRUS INATIVADOS TIPO 3...  10.588.595/0010-92
# 25845                                         VACINA BCG  33.485.939/0001-42
# 25846                                         VACINA BCG  33.485.939/0001-42
# 25896  VACINA INFLUENZA TRIVALENTE (INATIVADA, SUBUNI...  56.998.701/0001-16
# 25897  VACINA INFLUENZA TRIVALENTE (INATIVADA, SUBUNI...  56.998.701/0001-16
# 25898  VACINA INFLUENZA TRIVALENTE (INATIVADA, SUBUNI...  56.998.701/0001-16
# 25904                           VACINA RAIVA (INATIVADA)  10.588.595/0010-92
# 25905                           VACINA RAIVA (INATIVADA)  10.588.595/0010-92
# 25906                           VACINA RAIVA (INATIVADA)  10.588.595/0010-92
# 26329                         VÍRUS 17D DA FEBRE AMARELA  10.588.595/0010-92
#
#                                              LABORATÓRIO     CÓDIGO GGREM  \
# 865                                            MERCK S/A  525425110054703
# 866                                            MERCK S/A  525413070044403
# 948                                            MERCK S/A  525413010043803
# 949                                            MERCK S/A  525413010043903
# 950                                            MERCK S/A  525413010044003
# 1366                    SANOFI MEDLEY FARMACÊUTICA LTDA.  576720060071517
# 2512                                           MERCK S/A  525420402151415
# 2513                                           MERCK S/A  525420401153414
# 3496                            GERMED FARMACEUTICA LTDA  526136301113413
# 3497                            GERMED FARMACEUTICA LTDA  526121120145603
# 3499                           ABBVIE FARMACÊUTICA LTDA.  543715070001517
# 3838            BLANVER FARMOQUIMICA E FARMACEUTICA S.A.  544225030004503
# 7363                               EMS SIGMA PHARMA LTDA  531601106115417
# 7364                               EMS SIGMA PHARMA LTDA  531601107111415
# 7365                               EMS SIGMA PHARMA LTDA  531601103116412
# 7366                               EMS SIGMA PHARMA LTDA  531601102136411
# 7367                               EMS SIGMA PHARMA LTDA  531613020068803
# 8723                            GERMED FARMACEUTICA LTDA  526127302110117
# 8724                            GERMED FARMACEUTICA LTDA  526117120098206
# 9600                  ABBOTT LABORATORIOS DO BRASIL LTDA  500209903165419
# 9601                  ABBOTT LABORATORIOS DO BRASIL LTDA  500209901162412
# 9602                  ABBOTT LABORATORIOS DO BRASIL LTDA  500209902169410
# 12241                VIATRIS FARMACEUTICA DO BRASIL LTDA  541517070004017
# 12242                VIATRIS FARMACEUTICA DO BRASIL LTDA  541517070004117
# 12243                VIATRIS FARMACEUTICA DO BRASIL LTDA  541517070004217
# 12244                VIATRIS FARMACEUTICA DO BRASIL LTDA  541517070004317
# 12245                VIATRIS FARMACEUTICA DO BRASIL LTDA  541517070004417
# 12246                VIATRIS FARMACEUTICA DO BRASIL LTDA  541517070004517
# 12247                VIATRIS FARMACEUTICA DO BRASIL LTDA  541517070004617
# 12248                VIATRIS FARMACEUTICA DO BRASIL LTDA  541517070004717
# 12249                VIATRIS FARMACEUTICA DO BRASIL LTDA  541517070004817
# 12250                VIATRIS FARMACEUTICA DO BRASIL LTDA  541517070005017
# 12251                VIATRIS FARMACEUTICA DO BRASIL LTDA  541517070004917
# 12252                VIATRIS FARMACEUTICA DO BRASIL LTDA  541517070005117
# 16363  FUNDAÇÃO BAIANA DE PESQ. CIENTIFICA E DESENV. ...  544018060000307
# 16364  FUNDAÇÃO BAIANA DE PESQ. CIENTIFICA E DESENV. ...  544018070000407
# 18816                           LABORATORIOS PFIZER LTDA  522213060055903
# 19533                    JANSSEN-CILAG FARMACEUTICA LTDA  514525110044502
# 19534                    JANSSEN-CILAG FARMACEUTICA LTDA  514525110044402
# 21301  COSMED INDUSTRIA DE COSMETICOS E MEDICAMENTOS ...  540917060031217
# 21738                                 PFIZER BRASIL LTDA  522720060088117
# 21739                                 PFIZER BRASIL LTDA  522720060088217
# 21750                   SANOFI MEDLEY FARMACÊUTICA LTDA.  576720060071117
# 23890           ASPEN PHARMA INDÚSTRIA FARMACÊUTICA LTDA  505613040037414
# 24180                        GLAXOSMITHKLINE BRASIL LTDA  510603801111310
# 24181                        GLAXOSMITHKLINE BRASIL LTDA  510603802116316
# 25481                   SANOFI MEDLEY FARMACÊUTICA LTDA.  576720060072517
# 25484                   SANOFI MEDLEY FARMACÊUTICA LTDA.  576720060071217
# 25845                         FUNDACAO ATAULPHO DE PAIVA  509700103150414
# 25846                         FUNDACAO ATAULPHO DE PAIVA  509700101158418
# 25896                 ABBOTT LABORATORIOS DO BRASIL LTDA  500213040030713
# 25897                 ABBOTT LABORATORIOS DO BRASIL LTDA  500215070034203
# 25898                 ABBOTT LABORATORIOS DO BRASIL LTDA  500215070034103
# 25904                   SANOFI MEDLEY FARMACÊUTICA LTDA.  576720060073317
# 25905                   SANOFI MEDLEY FARMACÊUTICA LTDA.  576720060073417
# 25906                   SANOFI MEDLEY FARMACÊUTICA LTDA.  576720060073517
# 26329                   SANOFI MEDLEY FARMACÊUTICA LTDA.  576720070080417
#
#             REGISTRO          EAN 1          EAN 2       EAN 3  \
# 865    1008903760046  4065273472585         -           -
# 866    1008903760054  7891721027963         -           -
# 948    1008903630096  7891721027802         -           -
# 949    1008903630101  7891721027819         -           -
# 950    1008903630118  7891721027826         -           -
# 1366   1832603960019  8806689009134         -           -
# 2512   1008903510023  7891721022418         -           -
# 2513   1008903510041  7891721022425         -           -
# 3496   1058307120012  7894916500685  7896004775340      -
# 3497   1058307120039  7896004780801         -           -
# 3499   1986000050016  8054083003689         -           -
# 3838   1152400240011  7898581711315         -           -
# 7363   1356905980034  7894916502344         -           -
# 7364   1356905980042  7894916203524         -           -
# 7365   1356905980093  7894916203517         -           -
# 7366   1356905980174  7894916201353         -           -
# 7367   1356905980220  7894916509497         -           -
# 8723   1058308460021  7896004709369         -           -
# 8724   1058308460062  7896004709352         -           -
# 9600   1055303080062  7896255763172         -           -
# 9601   1055303080135  7896255764506         -           -
# 9602   1055303080143  7896255765619         -           -
# 12241  1883000210012  7898560663239         -           -
# 12242  1883000210020  7898560663253         -           -
# 12243  1883000210039  7898560663260         -           -
# 12244  1883000210047  7898560663277         -           -
# 12245  1883000210055  7898560663291         -           -
# 12246  1883000210063  7898560663314         -           -
# 12247  1883000210071  7898560663321         -           -
# 12248  1883000210081  7898560663338         -           -
# 12249  1883000210098  7898560663222         -           -
# 12250  1883000210101  7898560663284         -           -
# 12251  1883000210111  7898560663246         -           -
# 12252  1883000210128  7898560663307         -           -
# 16363  1988300040012  7898604730064         -           -
# 16364  1988300050018  7898604730071         -           -
# 18816  1021601820019  7891268105018         -           -
# 19533  1123634480015  0789621248569         -           -
# 19534  1123634480023  0789621248568         -           -
# 21301  1781707950011  7891142137135         -           -
# 21738  1211004680018  7891045010627         -           -
# 21739  1211004680026  7891045010771         -           -
# 21750  1832603980011  7891058999568         -           -
# 23890  1376401320027  7895858007768         -           -
# 24180  1010701940010  7896269900532         -           -
# 24181  1010701940029  7896269900853         -           -
# 25481  1832603460016  7891058021269         -           -
# 25484  1832603890010  7891058999599         -           -
# 25845  1016600010068  7898160920060         -           -
# 25846  1016600010076  7898160920053         -           -
# 25896  1055303360014  7896253902269         -           -
# 25897  1055303360081  7891158102073         -           -
# 25898  1055303360091  7891158102042         -           -
# 25904  1832603940018  3660053084265         -           -
# 25905  1832603940034  7891058022082         -           -
# 25906  1832603940042  7891058022099         -           -
# 26329  1832604140015  7891058999582         -           -
#
#                                                  PRODUTO  \
# 865                                              OVIDREL
# 866                                              OVIDREL
# 948                                              GONAL F
# 949                                              GONAL F
# 950                                              GONAL F
# 1366                                             EUVAX B
# 2512                                               REBIF
# 2513                                               REBIF
# 3496                                          SIGMATRIOL
# 3497                                          SIGMATRIOL
# 3499                                            CALCIJEX
# 3838                                          INJECTAFER
# 7363                                             DAFORIN
# 7364                                             DAFORIN
# 7365                                             DAFORIN
# 7366                                             DAFORIN
# 7367                                             DAFORIN
# 8723                            CLORIDRATO DE RANITIDINA
# 8724                            CLORIDRATO DE RANITIDINA
# 9600                                         IRUXOL MONO
# 9601                                         IRUXOL MONO
# 9602                                         IRUXOL MONO
# 12241                                            CUTENOX
# 12242                                            CUTENOX
# 12243                                            CUTENOX
# 12244                                            CUTENOX
# 12245                                            CUTENOX
# 12246                                            CUTENOX
# 12247                                            CUTENOX
# 12248                                            CUTENOX
# 12249                                            CUTENOX
# 12250                                            CUTENOX
# 12251                                            CUTENOX
# 12252                                            CUTENOX
# 16363                     BAHIAFARMA INSULINA HUMANA NPH
# 16364                       BAHIAFARMA INSULINA HUMANA R
# 18816                                        MIANTREX CS
# 19533                                             IMAAVY
# 19534                                             IMAAVY
# 21301                                            PRATIUM
# 21738                                        PREVENAR 13
# 21739                                        PREVENAR 13
# 21750        VACINA HAEMOPHILUS INFLUENZAE B (CONJUGADA)
# 23890                                           EUTROPIN
# 24180                                            IMIGRAN
# 24181                                            IMIGRAN
# 25481  VACINA ADSORVIDA DIFTERIA, TÉTANO E PERTUSIS (...
# 25484                                           TETRAXIM
# 25845                                         VACINA BCG
# 25846                                         VACINA BCG
# 25896                                           INFLUVAC
# 25897                                           INFLUVAC
# 25898                                           INFLUVAC
# 25904                           VACINA RAIVA (INATIVADA)
# 25905                           VACINA RAIVA (INATIVADA)
# 25906                           VACINA RAIVA (INATIVADA)
# 26329                                           STAMARIL
#
#                                             APRESENTAÇÃO  ... PMC 23 %  ALC  \
# 865            250 MCG SOL INJ CT 1 SER PREENCH X 0,5 ML  ...        672,34
# 866    250 MCG SOL INJ CT CAN APLIC CAR VD TRANS X 0,...  ...        672,34
# 948    300 UI SOL INJ SC CT CAN APLIC CARVD TRANS X 0...  ...       1444,40
# 949    450 UI SOL INJ SC CT  CAN APLIC CAR VD TRANS X...  ...       2166,70
# 950    900 UI SOL INJ SC CT CAN APLIC CAR VD TRANS X ...  ...       4333,37
# 1366          20MCG/ML SUS INJ CT FA VD TRANS X 0,5 ML    ...         64,93
# 2512   22 MCG SOL INJ CT 12 SER PREENC VD TRANS X 0,5...  ...      19548,20
# 2513   44 MCG SOL INJ CT 12 SER PREENC VD TRANS X 0,5...  ...      22239,42
# 3496                0,25 MCG CAP MOLE CT FR VD AMB X 30   ...        206,43
# 3497                 0,25 MCG CAP MOLE CT FR VD AMB X 90  ...        606,13
# 3499             1 MCG/ML SOL INJ CX 3 AMP VD AMB X 1 ML  ...           NaN
# 3838        50 MG/ML SOL INJ IV CT 1 FA VD TRANS X 10 ML  ...           NaN
# 7363          20 MG COM REV CT BL AL PLAS PVC TRANS X 20  ...         72,26
# 7364          20 MG COM REV CT BL AL PLAS PVC TRANS X 30  ...        103,21
# 7365             10 MG CAP DURA CT BL AL PLAS TRANS X 20  ...         50,42
# 7366         20 MG/ML SOL CT FR GOT PLAS TRANSL X 20 ML   ...         77,94
# 7367          20 MG COM REV CT BL AL PLAS PVC TRANS X 60  ...        206,45
# 8723                     150 MG COM REV CT BL AL/AL X 20  ...         76,39
# 8724                     300 MG COM REV CT BL AL/AL X 20  ...        159,30
# 9600                   1,2 U/G POM DERM CT BG AL X 30 G   ...        115,97
# 9601                1,2 U/G POM DERM CT 50 BG AL X 30 G   ...       5373,87
# 9602                    1,2 U/G POM DERM CT BG AL X 15 G  ...         74,31
# 12241  20 MG SOL INJ CT 10 SER VD INC PREENCHIDA X 0,...  ...        471,66
# 12242  40 MG SOL INJ CT 10 SER VD INC PREENCHIDA X 0,...  ...        916,38
# 12243  60 MG SOL INJ CT 2 SER VD INC PREENCHIDA X 0,6...  ...        280,95
# 12244  80 MG SOL INJ CT 2 SER VD INC PREENCHIDA X 0,8...  ...        374,16
# 12245  20 MG SOL INJ CT 10 SER VD INC PREENCHIDA X 0,...  ...        459,23
# 12246  40 MG SOL INJ CT 10 SER VD INC PREENCHIDA X 0,...  ...        892,27
# 12247  60 MG SOL INJ CT 2 SER VD INC PREENCHIDA X 0,6...  ...        273,59
# 12248  80 MG SOL INJ CT 2 SER VD INC PREENCHIDA X 0,8...  ...        364,29
# 12249     20 MG SOL INJ CT 02 SER VD INC PREENC X 0,2 ML  ...         93,04
# 12250  20 MG SOL INJ CT 02 SER VD INC  X 0,2 ML + SIS...  ...         91,82
# 12251     40 MG SOL INJ CT 02 SER VD INC PREENC X 0,4 ML  ...        180,84
# 12252  40 MG SOL INJ CT 02 SER VD INC X 0,4 ML + SIST...  ...        178,42
# 16363             100 UI/ML SUS INJ CT FA VD INC X 10 ML  ...        70,01*
# 16364             100 UI/ML SOL INJ CT FA VD INC X 10 ML  ...         73,03
# 18816  100 MG/ML SOL INJ CT FA PLAS TRANS X 10 ML (RE...  ...        376,38
# 19533      1200 MG SOL DIL INFUS CT FA VD TRANS X 6,5 ML  ...     120534,83
# 19534      300 MG SOL DIL INFUS CT FA VD TRANS X 1,62 ML  ...      30133,71
# 21301        140 MG/ML SUS OR CT FR PLAS OPC GOT X 15 ML  ...         37,22
# 21738   SUS INJ CT EST 01 SER PREENCH X 0,5 ML + 01 AGU   ...        341,71
# 21739  SUS INJ CT 2 EST X 5 SER PREENCH X 0,5 ML + 10...  ...       3417,41
# 21750  PO LIOF INJ CT FA VD TRANS + SER DIL C/ AGU AC...  ...         67,75
# 23890  4 UI PO LIOF CT 5 FA VD INC + 5 FA VD INC SOL ...  ...       1791,69
# 24180                     100 MG COM REV CT BL AL/AL X 2  ...        136,27
# 24181                      50 MG COM REV CT BL AL/AL X 2  ...         51,21
# 25481         1 DOSE IMU SUS INJ CT FR VD TRANS X 0,5ML   ...        110,10
# 25484  SUS INJ CT SER PREENC VD TRANS X 0,5 ML C/ AGU...  ...        169,42
# 25845  1MG PÓ LIOF INJ CX 25 AMP VD AMB + 25 AMP DIL ...  ...       865,19*
# 25846  1 MG PÓ LIOF INJ CX 01 AMP VD AMB + 1 AMP DIL ...  ...           NaN
# 25896          SUS INJ CT 1 SER PREENC VD TRANS X 0,5 ML  ...         89,18
# 25897  SUS INJ CT 10 SER LONG PREENC VD TRANS S/ AGU ...  ...        891,76
# 25898  SUS INJ CT 1 SER LONG PREENC VD TRANS COM AGU ...  ...         89,18
# 25904  3,25 UI PO LIOF SOL INJ CT FR VD TRANS + SER D...  ...        183,75
# 25905  3,25 UI PO LIOF SOL INJ CT 5 FR VD TRANS + 5 S...  ...           NaN
# 25906  3,25 UI PO LIOF SOL INJ CT 10 FR VD TRANS + 10...  ...           NaN
# 26329  PÓ LIOF SUS INJ X 1 DOSE CT 1 FA VD TRANS + SE...  ...        136,79
#
#       RESTRIÇÃO HOSPITALAR  CAP CONFAZ 87 ICMS 0% ANÁLISE RECURSAL  \
# 865                    Não  Não       Não     Não              NaN
# 866                    Não  Não       Não     Não              NaN
# 948                    Não  Não       Não     Não              NaN
# 949                    Não  Não       Não     Não              NaN
# 950                    Não  Não       Não     Não              NaN
# 1366                   Não  Não       Sim     Não              NaN
# 2512                   Não  Sim       Sim     Não              NaN
# 2513                   Não  Sim       Sim     Não              NaN
# 3496                   Não  Sim       Sim     Não              NaN
# 3497                   Não  Sim       Sim     Não              NaN
# 3499                   Sim  Sim       Sim     Não              NaN
# 3838                   Sim  Não       Não     Não              NaN
# 7363                   Não  Não       Não     Não              NaN
# 7364                   Não  Não       Não     Não              NaN
# 7365                   Não  Não       Não     Não              NaN
# 7366                   Não  Não       Não     Não              NaN
# 7367                   Não  Não       Não     Não              NaN
# 8723                   Não  Não       Não     Não              NaN
# 8724                   Não  Não       Não     Não              NaN
# 9600                   Não  Não       Não     Não             (AR)
# 9601                   Não  Não       Não     Não             (AR)
# 9602                   Não  Não       Não     Não             (AR)
# 12241                  Não  Não       Não     Não              NaN
# 12242                  Não  Sim       Não     Não              NaN
# 12243                  Não  Não       Não     Não              NaN
# 12244                  Não  Não       Não     Não              NaN
# 12245                  Não  Não       Não     Não              NaN
# 12246                  Não  Sim       Não     Não              NaN
# 12247                  Não  Não       Não     Não              NaN
# 12248                  Não  Não       Não     Não              NaN
# 12249                  Não  Não       Não     Não              NaN
# 12250                  Não  Não       Não     Não              NaN
# 12251                  Não  Sim       Não     Não              NaN
# 12252                  Não  Sim       Não     Não              NaN
# 16363                  Não  Sim       Sim     Sim              NaN
# 16364                  Não  Sim       Não     Não              NaN
# 18816                  Não  Não       Não     Não              NaN
# 19533                  Não  Não       Não     Não              NaN
# 19534                  Não  Não       Não     Não              NaN
# 21301                  Não  Não       Não     Não              NaN
# 21738                  Não  Não       Sim     Não              NaN
# 21739                  Não  Não       Sim     Não              NaN
# 21750                  Não  Não       Sim     Não              NaN
# 23890                  Não  Sim       Sim     Não              NaN
# 24180                  Não  Não       Não     Não              NaN
# 24181                  Não  Não       Não     Não              NaN
# 25481                  Não  Não       Sim     Não              NaN
# 25484                  Não  Não       Sim     Não              NaN
# 25845                  Não  Não       Sim     Sim              NaN
# 25846                  Sim  Não       Sim     Sim              NaN
# 25896                  Não  Não       Não     Não              NaN
# 25897                  Não  Não       Sim     Não              NaN
# 25898                  Não  Não       Sim     Não              NaN
# 25904                  Não  Não       Sim     Não              NaN
# 25905                  Sim  Não       Sim     Não              NaN
# 25906                  Sim  Não       Sim     Não              NaN
# 26329                  Não  Não       Sim     Não              NaN
#
#       LISTA DE CONCESSÃO DE CRÉDITO TRIBUTÁRIO (PIS/COFINS)  \
# 865                                             Positiva
# 866                                             Positiva
# 948                                             Positiva
# 949                                             Positiva
# 950                                             Positiva
# 1366                                            Positiva
# 2512                                            Positiva
# 2513                                            Positiva
# 3496                                            Positiva
# 3497                                            Positiva
# 3499                                            Positiva
# 3838                                            Negativa
# 7363                                            Positiva
# 7364                                            Positiva
# 7365                                            Positiva
# 7366                                            Positiva
# 7367                                            Positiva
# 8723                                            Positiva
# 8724                                            Positiva
# 9600                                            Negativa
# 9601                                            Negativa
# 9602                                            Negativa
# 12241                                           Positiva
# 12242                                           Positiva
# 12243                                           Positiva
# 12244                                           Positiva
# 12245                                           Positiva
# 12246                                           Positiva
# 12247                                           Positiva
# 12248                                           Positiva
# 12249                                           Positiva
# 12250                                           Positiva
# 12251                                           Positiva
# 12252                                           Positiva
# 16363                                           Positiva
# 16364                                           Positiva
# 18816                                           Positiva
# 19533                                           Negativa
# 19534                                           Negativa
# 21301                                           Negativa
# 21738                                           Positiva
# 21739                                           Positiva
# 21750                                           Positiva
# 23890                                           Positiva
# 24180                                           Positiva
# 24181                                           Positiva
# 25481                                           Positiva
# 25484                                           Positiva
# 25845                                           Positiva
# 25846                                           Positiva
# 25896                                           Positiva
# 25897                                           Positiva
# 25898                                           Positiva
# 25904                                           Positiva
# 25905                                           Positiva
# 25906                                           Positiva
# 26329                                           Positiva
#
#       COMERCIALIZAÇÃO 2024                         TARJA DESTINAÇÃO COMERCIAL
# 865                    Não                        - (*)                    NaN
# 866                    Sim                        - (*)                    NaN
# 948                    Sim                        - (*)                    NaN
# 949                    Sim                        - (*)                    NaN
# 950                    Sim                        - (*)                    NaN
# 1366                   Não                        - (*)                    NaN
# 2512                   Sim                        - (*)                    NaN
# 2513                   Sim                        - (*)                    NaN
# 3496                   Sim                        - (*)                    NaN
# 3497                   Sim                        - (*)                    NaN
# 3499                   Sim                        - (*)                    NaN
# 3838                   Não                Tarja Vermelha                   NaN
# 7363                   Não                Tarja Vermelha                   NaN
# 7364                   Sim                Tarja Vermelha                   NaN
# 7365                   Sim  Tarja Vermelha sob restrição                   NaN
# 7366                   Sim  Tarja Vermelha sob restrição                   NaN
# 7367                   Sim                Tarja Vermelha                   NaN
# 8723                   Não                Tarja Vermelha                   NaN
# 8724                   Não                Tarja Vermelha                   NaN
# 9600                   Sim                        - (*)                    NaN
# 9601                   Sim                        - (*)                    NaN
# 9602                   Sim                        - (*)                    NaN
# 12241                  Sim                        - (*)                    NaN
# 12242                  Sim                        - (*)                    NaN
# 12243                  Sim                        - (*)                    NaN
# 12244                  Sim                        - (*)                    NaN
# 12245                  Sim                        - (*)                    NaN
# 12246                  Sim                        - (*)                    NaN
# 12247                  Sim                        - (*)                    NaN
# 12248                  Sim                        - (*)                    NaN
# 12249                  Não                        - (*)                    NaN
# 12250                  Sim                        - (*)                    NaN
# 12251                  Não                        - (*)                    NaN
# 12252                  Sim                        - (*)                    NaN
# 16363                  Sim                Tarja Vermelha                   NaN
# 16364                  Sim                        - (*)                    NaN
# 18816                  Não                        - (*)                    NaN
# 19533                  Não                Tarja Vermelha                   NaN
# 19534                  Não                Tarja Vermelha                   NaN
# 21301                  Sim               Tarja Sem Tarja                   NaN
# 21738                  Sim                Tarja Vermelha                   NaN
# 21739                  Não                Tarja Vermelha                   NaN
# 21750                  Sim                        - (*)                    NaN
# 23890                  Não                        - (*)                    NaN
# 24180                  Sim                Tarja Vermelha                   NaN
# 24181                  Sim                Tarja Vermelha                   NaN
# 25481                  Não                        - (*)                    NaN
# 25484                  Não                        - (*)                    NaN
# 25845                  Não                        - (*)                    NaN
# 25846                  Não                        - (*)                    NaN
# 25896                  Não                        - (*)                    NaN
# 25897                  Não                        - (*)                    NaN
# 25898                  Sim                        - (*)                    NaN
# 25904                  Não                        - (*)                    NaN
# 25905                  Não                        - (*)                    NaN
# 25906                  Não                        - (*)                    NaN
# 26329                  Sim                        - (*)                    NaN
#
# [57 rows x 74 columns]

# %%
nao_informado = medicamentos['TIPO DE PRODUTO (STATUS DO PRODUTO)'] == '    -     '
medicamentos.loc[nao_informado, 'TIPO DE PRODUTO (STATUS DO PRODUTO)'] = 'Não Informado'

# %%
medicamentos.loc[medicamentos['TIPO DE PRODUTO (STATUS DO PRODUTO)'] ==  'Genérico' , 'SUBSTÂNCIA'].count()
# Out:
# np.int64(9816)

# %%
medicamentos['preco_final_consumidor'] = medicamentos['PMC 18 %']\
    .str.replace('R$ ', '')\
    .str.replace(',', '.')\
    .str.replace('*', '')\
    .astype(float)
medicamentos['preco_final_consumidor']
# Out:
# 0          36.57
# 1        2530.19
# 2        8034.79
# 3        3805.12
# 4        7610.21
#           ...
# 26770      11.00
# 26771      12.65
# 26772     108.50
# 26773      11.85
# 26774      27.89
# Name: preco_final_consumidor, Length: 26775, dtype: float64

# %%
genericos = medicamentos['TIPO DE PRODUTO (STATUS DO PRODUTO)'] ==  'Genérico' 

## 12,45
## 44,31
medicamentos.loc[genericos,'preco_final_consumidor'] = \
    medicamentos.loc[genericos, 'PMC 0 %']\
    .str.replace(',', '.')\
    .str.replace('*', '')\
    .astype(float)

# %%
medicamentos.loc[genericos,'preco_final_consumidor']
# Out:
# 15          21.07
# 16          29.69
# 20          21.03
# 21          29.69
# 22          21.03
#            ...
# 26653     1396.89
# 26654     1278.64
# 26655     1278.65
# 26656     5114.57
# 26657    12786.45
# Name: preco_final_consumidor, Length: 9816, dtype: float64

# %%
colunas_para_remover = [
    'PF Sem Impostos', 'PF 0%', 'PF 12 %',
    'PF 12 %  ALC', 'PF 17 %', 'PF 17 %  ALC', 'PF 17,5 %',
    'PF 17,5 %  ALC', 'PF 18 %', 'PF 18 %  ALC', 'PF 19 %', 'PF 19 %  ALC',
    'PF 19,5 %', 'PF 19,5 %  ALC', 'PF 20 %', 'PF 20 %  ALC', 'PF 20,5 %',
    'PF 20,5 %  ALC', 'PF 21 %', 'PF 21 %  ALC', 'PF 22 %', 'PF 22 %  ALC',
    'PF 22,5 %', 'PF 22,5 %  ALC', 'PF 23 %', 'PF 23 %  ALC',
    'PMC Sem Impostos', 'PMC 0 %', 'PMC 12 %', 'PMC 12 %  ALC', 'PMC 17 %',
    'PMC 17 %  ALC', 'PMC 17,5 %', 'PMC 17,5 %  ALC', 'PMC 18 %',
    'PMC 18 %  ALC', 'PMC 19 %', 'PMC 19 %  ALC', 'PMC 19,5 %',
    'PMC 19,5 %  ALC', 'PMC 20 %', 'PMC 20 %  ALC', 'PMC 20,5 %',
    'PMC 20,5 %  ALC', 'PMC 21 %', 'PMC 21 %  ALC', 'PMC 22 %',
    'PMC 22 %  ALC', 'PMC 22,5 %', 'PMC 22,5 %  ALC', 'PMC 23 %',
    'PMC 23 %  ALC', 'ICMS 0%'
]
medicamentos.drop(columns=colunas_para_remover, inplace=True)

# %%
import pandas as pd

medicamentos = pd.read_csv('medicamentos_limpo.csv')
medicamentos.columns
# Out:
# Index(['ativo', 'CNPJ', 'laboratorio', 'registro', 'EAN 1', 'EAN 2', 'EAN 3',
#        'produto', 'apresentacao', 'classe_terapeutica', 'tipo_produto',
#        'regime_preco', 'restricao_hospitalar', 'comercializavel', 'tarja',
#        'preco_final_consumidor'],
#       dtype='object')

# %%
medicamentos.columns = medicamentos.columns.str.strip()
medicamentos['DESTINAÇÃO COMERCIAL']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 26770   NaN
# 26771   NaN
# 26772   NaN
# 26773   NaN
# 26774   NaN
# Name: DESTINAÇÃO COMERCIAL, Length: 26775, dtype: float64

# %%
# CAP = Coeficiente de Adequação de Preços, ) é um desconto mínimo obrigatório que empresas de medicamentos devem aplicar nas vendas para o governo
# CONFAZ 87 = Convênio ICMS 87/99, que estabelece regras para a cobrança do ICMS nas operações para o governo
colunas_para_remover = [
    'CÓDIGO GGREM', 'CAP', 'CONFAZ 87', 'ANÁLISE RECURSAL',
    'LISTA DE CONCESSÃO DE CRÉDITO TRIBUTÁRIO (PIS/COFINS)',
    'DESTINAÇÃO COMERCIAL'
]
medicamentos.drop(columns=colunas_para_remover, inplace=True)

# %%
medicamentos.columns
# Out:
# Index(['SUBSTÂNCIA', 'CNPJ', 'LABORATÓRIO', 'REGISTRO', 'EAN 1', 'EAN 2',
#        'EAN 3', 'PRODUTO', 'APRESENTAÇÃO', 'CLASSE TERAPÊUTICA',
#        'TIPO DE PRODUTO (STATUS DO PRODUTO)', 'REGIME DE PREÇO',
#        'RESTRIÇÃO HOSPITALAR', 'COMERCIALIZAÇÃO 2024', 'TARJA',
#        'preco_final_consumidor'],
#       dtype='object')

# %%
medicamentos.rename(
    columns={
    'SUBSTÂNCIA': 'ativo',
    'LABORATÓRIO': 'laboratorio',
    'REGISTRO': 'registro',
    'PRODUTO': 'produto',
    'APRESENTAÇÃO': 'apresentacao',
    'CLASSE TERAPÊUTICA': 'classe_terapeutica',
    'TIPO DE PRODUTO (STATUS DO PRODUTO)': 'tipo_produto',
    'REGIME DE PREÇO': 'regime_preco',
    'RESTRIÇÃO HOSPITALAR': 'restricao_hospitalar',
    'COMERCIALIZAÇÃO 2024': 'comercializavel',
    'TARJA': 'tarja'
    }, 
    inplace=True
)

# %%
medicamentos.columns
# Out:
# Index(['ativo', 'CNPJ', 'laboratorio', 'registro', 'EAN 1', 'EAN 2', 'EAN 3',
#        'produto', 'apresentacao', 'classe_terapeutica', 'tipo_produto',
#        'regime_preco', 'restricao_hospitalar', 'comercializavel', 'tarja',
#        'preco_final_consumidor'],
#       dtype='object')

# %%
medicamentos.head()
# Out:
#                                     ativo                CNPJ  \
# 0  21-ACETATO DE DEXAMETASONA;CLOTRIMAZOL  18.459.628/0001-15
# 1                              ABATACEPTE  56.998.982/0001-07
# 2                              ABATACEPTE  56.998.982/0001-07
# 3                            ABEMACICLIBE  43.940.618/0001-44
# 4                            ABEMACICLIBE  43.940.618/0001-44
#
#                               laboratorio       registro          EAN 1 EAN 2  \
# 0                              BAYER S.A.  1705600230032  7891106000956   NaN
# 1  BRISTOL-MYERS SQUIBB FARMACÊUTICA LTDA  1018003900019  7896016806469   NaN
# 2  BRISTOL-MYERS SQUIBB FARMACÊUTICA LTDA  1018003900078  7896016808197   NaN
# 3                ELI LILLY DO BRASIL LTDA  1126001990018  7896382708442   NaN
# 4                ELI LILLY DO BRASIL LTDA  1126001990034  7896382708466   NaN
#
#   EAN 3     produto                                       apresentacao  \
# 0   NaN  BAYCUTEN N     10 MG/G + 0,443 MG/G CREM DERM CT BG AL X 40 G
# 1   NaN     ORENCIA   250 MG PO LIOF SOL INJ CT 1 FA + SER DESCARTÁVEL
# 2   NaN     ORENCIA  125 MG/ML SOL INJ SC CT 4 SER PREENC VD TRANS ...
# 3   NaN   VERZENIOS                     50 MG COM REV CT BL AL AL X 30
# 4   NaN   VERZENIOS                    100 MG COM REV CT BL AL AL X 30
#
#                                   classe_terapeutica tipo_produto  \
# 0  D7B2 - CORTICOESTERÓIDES ASSOCIADOS A ANTIMICO...         Novo
# 1          M1C - AGENTES ANTI-REUMÁTICOS ESPECÍFICOS    Biológico
# 2          M1C - AGENTES ANTI-REUMÁTICOS ESPECÍFICOS    Biológico
# 3               L1H - INIBIDORES DE PROTEINA QUINASE         Novo
# 4               L1H - INIBIDORES DE PROTEINA QUINASE         Novo
#
#   regime_preco  restricao_hospitalar  comercializavel           tarja  \
# 0     Regulado                 False             True       Sem Tarja
# 1     Regulado                  True             True  Tarja Vermelha
# 2     Regulado                 False             True       Sem Tarja
# 3     Regulado                 False             True  Tarja Vermelha
# 4     Regulado                 False             True  Tarja Vermelha
#
#    preco_final_consumidor
# 0                   36.57
# 1                 2530.19
# 2                 8034.79
# 3                 3805.12
# 4                 7610.21

# %%
medicamentos['preco_final_consumidor'].head()
# Out:
# 0      36.57
# 1    2530.19
# 2    8034.79
# 3    3805.12
# 4    7610.21
# Name: preco_final_consumidor, dtype: float64

# %%
medicamentos.to_csv('medicamentos_limpo.csv', index=False)

# %%
medicamentos['EAN 1'] = medicamentos['EAN 1'].astype(str)
medicamentos['EAN 2'] = medicamentos['EAN 2'].astype(str)
medicamentos['EAN 3'] = medicamentos['EAN 3'].astype(str)

# %%
medicamentos.replace('    -     ', np.nan, inplace=True)

# %%
medicamentos['restricao_hospitalar'].unique()
# Out:
# array(['Não', 'Sim'], dtype=object)

# %%
medicamentos['restricao_hospitalar'] = medicamentos['restricao_hospitalar'] == 'Sim'

# %%
medicamentos['comercializavel'].unique()
# Out:
# array(['Sim', 'Não'], dtype=object)

# %%
medicamentos['comercializavel'] = medicamentos['comercializavel'] == 'Sim'

# %%
medicamentos['comercializavel']
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 26770    False
# 26771    False
# 26772     True
# 26773    False
# 26774    False
# Name: comercializavel, Length: 26775, dtype: bool

# %%
medicamentos['tarja'].unique()
# Out:
# array(['- (*) ', 'Tarja Vermelha', 'Tarja Vermelha sob restrição',
#        'Tarja Sem Tarja', 'Tarja Preta'], dtype=object)

# %%
sem_tarja = medicamentos['tarja'] == 'Tarja Sem Tarja'
sem_tarja_definida = medicamentos['tarja'].str.contains('(*)', regex=False)

medicamentos.loc[sem_tarja, 'tarja'] = 'Sem Tarja'
medicamentos.loc[sem_tarja_definida, 'tarja'] = 'Sem Tarja'
medicamentos['tarja'].unique()
# Out:
# array(['Sem Tarja', 'Tarja Vermelha', 'Tarja Vermelha sob restrição',
#        'Tarja Preta'], dtype=object)

# %%
medicamentos['EAN 1'] = medicamentos['EAN 1'].str.replace('.0', '', regex=False)

# %%
(medicamentos['EAN 1'] == "7896472515363").any()
# Out:
# np.True_

# %%
medicamentos['registro'] = medicamentos['registro'].astype(str)

# %%
(medicamentos['registro'] == "1384100590018").any()
# Out:
# np.False_

# %%
def buscar_remedios(termo_busca, df):
    """
    Busca por medicamentos no DataFrame fornecido.
    Ignora maiúsculas/minúsculas e acentuacão.
    """
    termo_busca = str(termo_busca).strip() # removeu espaços extras
    busca_ean = df['EAN 1'] == termo_busca
    
    if busca_ean.any():
        print(f"✅ Encontrado por Código de Barras (EAN): {termo_busca}")
        return df[busca_ean]
    
    elif (df['registro'] == termo_busca).any():
        print(f"✅ Encontrado por Registro: {termo_busca}")
        return df[df['registro'] == termo_busca]
    
    # segunda tentativa
    busca_por_ativo = df['ativo'].str.contains(termo_busca, case=False, na=False)
    
    if busca_por_ativo.any():
        print(f"✅ Encontrado por Princípio Ativo: '{termo_busca}'")
        return df[busca_por_ativo]
    
    # não achou nada
    print(f"❌ Nenhum medicamento encontrado para: '{termo_busca}'")
    return None

# %%
primeiro_filtro = medicamentos['produto'].str.contains("dorflex", case=False, na=False)
segundo_filtro = pd.Series([False]*len(medicamentos))
(primeiro_filtro | segundo_filtro).any()
# Out:
# np.True_

# %%
import unicodedata

def buscar_remedios(termo_busca, df):
    """
    Busca por medicamentos no DataFrame fornecido.
    Ignora maiúsculas/minúsculas e acentuacão.
    """
    termo_busca = str(termo_busca).strip()   
    termo_limpo = unicodedata.normalize('NFKD', termo_busca).encode('ascii', errors='ignore').decode('utf-8')

    busca_ean = df['registro'] == termo_busca
    
    if busca_ean.any():
        print(f"✅ Encontrado por Código de registro: {termo_busca}")
        return df[busca_ean]
    elif (df['EAN 1'] == termo_busca).any():
        print(f"✅ Encontrado por EAN 1: {termo_busca}")
        return df[df['EAN 1'] == termo_busca]

    mask_ativo = df['ativo'].str.contains(termo_limpo, case=False, na=False, regex=False)
    mask_produto = df['produto'].str.contains(termo_limpo, case=False, na=False, regex=False)

    resultados = df[mask_ativo | mask_produto]

    if not resultados.empty:
        print(f"✅ Encontrado(s) {len(resultados)} resultado(s) para: {termo_busca}")
        return resultados.head(10)
    else:
        print(f"❌ Nenhum resultado encontrado para: {termo_busca}")
        return pd.DataFrame()

# %%
termo_digitado = input("qual medicamento você quer buscar? ")
resultado = buscar_remedios(termo_digitado, medicamentos)
display(resultado)
# Out:
# ❌ Nenhum resultado encontrado para: dipirona$
# Empty DataFrame
# Columns: []
# Index: []

# %%
termo_limpo = "dorflex"
ativo_limpo = medicamentos['ativo'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8')
produto_limpo = medicamentos['produto'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8')

mask_ativo = ativo_limpo.str.contains(termo_limpo, case=False, na=False)
mask_produto = produto_limpo.str.contains(termo_limpo, case=False, na=False)

resultados = medicamentos[mask_ativo | mask_produto]
resultados
# Out:
#                                                    ativo                CNPJ  \
# 11649                              DIPIRONA MONOIDRATADA  10.588.595/0010-92
# 11650                              DIPIRONA MONOIDRATADA  10.588.595/0010-92
# 11651                              DIPIRONA MONOIDRATADA  10.588.595/0010-92
# 11652                              DIPIRONA MONOIDRATADA  10.588.595/0010-92
# 11663                              DIPIRONA MONOIDRATADA  38.391.432/0001-43
# 11664                              DIPIRONA MONOIDRATADA  38.391.432/0001-43
# 11665                              DIPIRONA MONOIDRATADA  38.391.432/0001-43
# 11666                              DIPIRONA MONOIDRATADA  38.391.432/0001-43
# 11667                              DIPIRONA MONOIDRATADA  38.391.432/0001-43
# 11668                              DIPIRONA MONOIDRATADA  38.391.432/0001-43
# 11749  DIPIRONA MONOIDRATADA;CAFEÍNA ANIDRA;CITRATO D...  38.391.432/0001-43
# 11750  DIPIRONA MONOIDRATADA;CAFEÍNA ANIDRA;CITRATO D...  38.391.432/0001-43
# 11751  DIPIRONA MONOIDRATADA;CAFEÍNA ANIDRA;CITRATO D...  38.391.432/0001-43
# 11752  DIPIRONA MONOIDRATADA;CAFEÍNA ANIDRA;CITRATO D...  38.391.432/0001-43
# 11753  DIPIRONA MONOIDRATADA;CAFEÍNA ANIDRA;CITRATO D...  38.391.432/0001-43
# 11754  DIPIRONA MONOIDRATADA;CAFEÍNA ANIDRA;CITRATO D...  38.391.432/0001-43
# 11755  DIPIRONA MONOIDRATADA;CAFEÍNA ANIDRA;CITRATO D...  38.391.432/0001-43
# 11756  DIPIRONA MONOIDRATADA;CAFEÍNA ANIDRA;CITRATO D...  38.391.432/0001-43
# 11757  DIPIRONA MONOIDRATADA;CAFEÍNA ANIDRA;CITRATO D...  38.391.432/0001-43
# 11758  DIPIRONA MONOIDRATADA;CAFEÍNA ANIDRA;CITRATO D...  38.391.432/0001-43
# 11759  DIPIRONA MONOIDRATADA;CAFEÍNA ANIDRA;CITRATO D...  38.391.432/0001-43
#
#                             laboratorio       registro         EAN 1  EAN 2  \
# 11649  SANOFI MEDLEY FARMACÊUTICA LTDA.  1832604600229  7.891058e+12    NaN
# 11650  SANOFI MEDLEY FARMACÊUTICA LTDA.  1832604600296  7.891058e+12    NaN
# 11651  SANOFI MEDLEY FARMACÊUTICA LTDA.  1832604600636  7.891058e+12    NaN
# 11652  SANOFI MEDLEY FARMACÊUTICA LTDA.  1832604600687  7.891058e+12    NaN
# 11663     OPELLA HEALTHCARE BRAZIL LTDA  1862000070651  7.891058e+12    NaN
# 11664     OPELLA HEALTHCARE BRAZIL LTDA  1862000090308  7.891058e+12    NaN
# 11665     OPELLA HEALTHCARE BRAZIL LTDA  1862000090324  7.891058e+12    NaN
# 11666     OPELLA HEALTHCARE BRAZIL LTDA  1862000090642  7.891058e+12    NaN
# 11667     OPELLA HEALTHCARE BRAZIL LTDA  1862000090650  7.891058e+12    NaN
# 11668     OPELLA HEALTHCARE BRAZIL LTDA  1862000090693  7.891058e+12    NaN
# 11749     OPELLA HEALTHCARE BRAZIL LTDA  1862000080051  7.891058e+12    NaN
# 11750     OPELLA HEALTHCARE BRAZIL LTDA  1862000080061  7.891058e+12    NaN
# 11751     OPELLA HEALTHCARE BRAZIL LTDA  1862000080078  7.891058e+12    NaN
# 11752     OPELLA HEALTHCARE BRAZIL LTDA  1862000080086  7.891058e+12    NaN
# 11753     OPELLA HEALTHCARE BRAZIL LTDA  1862000080116  7.891058e+12    NaN
# 11754     OPELLA HEALTHCARE BRAZIL LTDA  1862000080124  7.891058e+12    NaN
# 11755     OPELLA HEALTHCARE BRAZIL LTDA  1862000080140  7.891058e+12    NaN
# 11756     OPELLA HEALTHCARE BRAZIL LTDA  1862000080205  7.891058e+12    NaN
# 11757     OPELLA HEALTHCARE BRAZIL LTDA  1862000080231  7.891058e+12    NaN
# 11758     OPELLA HEALTHCARE BRAZIL LTDA  1862000080256  7.891058e+12    NaN
# 11759     OPELLA HEALTHCARE BRAZIL LTDA  1862000080272  7.891058e+12    NaN
#
#        EAN 3      produto                                       apresentacao  \
# 11649    NaN  DORFLEX UNO               1 G COM  CT BL AL PLAS TRANS X 100
# 11650    NaN  DORFLEX UNO                       1G COM EFEV CT STR AL AL X 6
# 11651    NaN  DORFLEX UNO                  1 G COM CT BL AL PLAS PVC OPC X 4
# 11652    NaN  DORFLEX UNO                 1 G COM CT BL AL PLAS PVC OPC X 92
# 11663    NaN  DORFLEX DIP                 1 G COM CT BL AL PLAS PVC OPC X 10
# 11664    NaN  DORFLEX UNO                      1G COM EFEV CT STR AL AL X 10
# 11665    NaN  DORFLEX UNO                     1G COM EFEV CT STR AL AL X 100
# 11666    NaN  DORFLEX UNO                 1 G COM CT BL AL PLAS PVC OPC X 10
# 11667    NaN  DORFLEX UNO                 1 G COM CT BL AL PLAS PVC OPC X 20
# 11668    NaN  DORFLEX UNO                1 G COM CT BL AL PLAS PVC OPC X 100
# 11749    NaN      DORFLEX  35 MG/ML + 300 MG/ML + 50 MG/ML SOL OR CT FR V...
# 11750    NaN      DORFLEX  35 MG + 300 MG + 50 MG COM CT BL AL PLAS  AMB ...
# 11751    NaN      DORFLEX  35 MG + 300 MG + 50 MG COM CT BL AL PLAS  AMB ...
# 11752    NaN      DORFLEX  35 MG + 300 MG + 50 MG COM CT BL AL PLAS  AMB ...
# 11753    NaN      DORFLEX  300 MG + 35 MG + 50 MG COM CT BL AL PLAS  AMB ...
# 11754    NaN      DORFLEX  300 MG + 35 MG + 50 MG COM CT BL AL PLAS  AMB ...
# 11755    NaN      DORFLEX  300 MG + 35 MG + 50 MG COM CT BL AL PLAS  AMB ...
# 11756    NaN      DORFLEX  300 MG + 35 MG + 50 MG COM CT BL AL PLAS  AMB ...
# 11757    NaN      DORFLEX  (600 + 70 + 100) MG COM CT BL AL PLAS PVC AMB X 8
# 11758    NaN      DORFLEX  (600 + 70 + 100) MG COM CT BL AL PLAS PVC AMB ...
# 11759    NaN      DORFLEX  (600 + 70 + 100) MG COM CT BL AL PLAS PVC AMB ...
#
#                                       classe_terapeutica tipo_produto  \
# 11649  N2B2 - ANALGÉSICOS NÃO NARCÓTICOS E ANTIPIRÉTI...      Similar
# 11650  N2B2 - ANALGÉSICOS NÃO NARCÓTICOS E ANTIPIRÉTI...      Similar
# 11651  N2B2 - ANALGÉSICOS NÃO NARCÓTICOS E ANTIPIRÉTI...      Similar
# 11652  N2B2 - ANALGÉSICOS NÃO NARCÓTICOS E ANTIPIRÉTI...      Similar
# 11663  N2B2 - ANALGÉSICOS NÃO NARCÓTICOS E ANTIPIRÉTI...      Similar
# 11664  N2B2 - ANALGÉSICOS NÃO NARCÓTICOS E ANTIPIRÉTI...      Similar
# 11665  N2B2 - ANALGÉSICOS NÃO NARCÓTICOS E ANTIPIRÉTI...      Similar
# 11666  N2B2 - ANALGÉSICOS NÃO NARCÓTICOS E ANTIPIRÉTI...      Similar
# 11667  N2B2 - ANALGÉSICOS NÃO NARCÓTICOS E ANTIPIRÉTI...      Similar
# 11668  N2B2 - ANALGÉSICOS NÃO NARCÓTICOS E ANTIPIRÉTI...      Similar
# 11749           M3B - RELAXANTE MUSCULAR DE AÇÃO CENTRAL         Novo
# 11750           M3B - RELAXANTE MUSCULAR DE AÇÃO CENTRAL         Novo
# 11751           M3B - RELAXANTE MUSCULAR DE AÇÃO CENTRAL         Novo
# 11752           M3B - RELAXANTE MUSCULAR DE AÇÃO CENTRAL         Novo
# 11753           M3B - RELAXANTE MUSCULAR DE AÇÃO CENTRAL         Novo
# 11754           M3B - RELAXANTE MUSCULAR DE AÇÃO CENTRAL         Novo
# 11755           M3B - RELAXANTE MUSCULAR DE AÇÃO CENTRAL         Novo
# 11756           M3B - RELAXANTE MUSCULAR DE AÇÃO CENTRAL         Novo
# 11757           M3B - RELAXANTE MUSCULAR DE AÇÃO CENTRAL         Novo
# 11758           M3B - RELAXANTE MUSCULAR DE AÇÃO CENTRAL         Novo
# 11759           M3B - RELAXANTE MUSCULAR DE AÇÃO CENTRAL         Novo
#
#       regime_preco  restricao_hospitalar  comercializavel      tarja  \
# 11649     Liberado                 False            False  Sem Tarja
# 11650     Liberado                 False             True  Sem Tarja
# 11651     Liberado                 False             True  Sem Tarja
# 11652     Liberado                 False             True  Sem Tarja
# 11663     Liberado                 False            False  Sem Tarja
# 11664     Liberado                 False            False  Sem Tarja
# 11665     Liberado                 False            False  Sem Tarja
# 11666     Liberado                 False            False  Sem Tarja
# 11667     Liberado                 False            False  Sem Tarja
# 11668     Liberado                 False            False  Sem Tarja
# 11749     Liberado                 False            False  Sem Tarja
# 11750     Liberado                 False            False  Sem Tarja
# 11751     Liberado                 False            False  Sem Tarja
# 11752     Liberado                 False            False  Sem Tarja
# 11753     Liberado                 False            False  Sem Tarja
# 11754     Liberado                 False            False  Sem Tarja
# 11755     Liberado                 False            False  Sem Tarja
# 11756     Liberado                 False            False  Sem Tarja
# 11757     Liberado                 False            False  Sem Tarja
# 11758     Liberado                 False            False  Sem Tarja
# 11759     Liberado                 False            False  Sem Tarja
#
#        preco_final_consumidor
# 11649                  143.24
# 11650                   25.52
# 11651                   13.46
# 11652                  155.35
# 11663                   12.99
# 11664                   24.60
# 11665                  249.26
# 11666                   13.76
# 11667                   22.27
# 11668                  159.72
# 11749                   18.67
# 11750                  128.39
# 11751                   13.84
# 11752                   15.57
# 11753                   17.70
# 11754                  186.65
# 11755                  180.98
# 11756                   21.13
# 11757                   12.52
# 11758                   22.62
# 11759                  140.18

# %%
[mask_ativo | mask_produto]
# Out:
# [0        False
#  1        False
#  2        False
#  3        False
#  4        False
#           ...
#  26770    False
#  26771    False
#  26772    False
#  26773    False
#  26774    False
#  Length: 26775, dtype: bool]

# %%
medicamentos['laboratorio'].value_counts()
# Out:
# laboratorio
# EMS S/A                                                1727
# ACHÉ LABORATÓRIOS FARMACÊUTICOS S.A                    1397
# EUROFARMA LABORATORIOS S.A.                            1211
# GERMED FARMACEUTICA LTDA                               1133
# PRATI DONADUZZI & CIA LTDA                             1130
#                                                        ...
# HEARST LABORATORIOS DO BRASIL LTDA                        1
# CATALENT BRASIL LTDA.                                     1
# LABORATÓRIO NEO QUÍMICA COMÉRCIO E INDÚSTRIA LTDA         1
# CML PRODUTOS MÉDICOS LTDA                                 1
# PANAMERICAN MEDICAL SUPPLY SUPRIMENTOS MEDICOS LTDA       1
# Name: count, Length: 259, dtype: int64

# %%
contagem_lab = medicamentos['laboratorio'].value_counts()\
    .sort_values(ascending=True)

ax1 = contagem_lab.plot(
    kind='barh', 
    figsize=(10, 10), 
    color="#27A9FF",
    title='Quantidade de Produtos por Laboratório',
    ylabel='',
)
ax1.set_yticklabels([])
ax1.set_ylabel('')
ax1

# 1. Encontrar 10 maiores laboratórios em número de produtos cadastrados
# 2. Encontrar 10 laboratórios com preço medio mais alto
# Out:
# <Axes: title={'center': 'Quantidade de Produtos por Laboratório'}>

# %%
medicamentos.groupby('laboratorio')['preco_final_consumidor']\
    .mean().sort_values(ascending=True).head(10)
# Out:
# laboratorio
# LABORATORIO SIMOES LTDA.                                 6.890000
# LABORATÓRIO NEO QUÍMICA COMÉRCIO E INDÚSTRIA LTDA       10.910000
# LABORATORIO INDUSTRIAL FARMACÊUTICO LIFAR LTDA          13.240000
# CASA GRANADO LABORATÓRIOS, FARMÁCIAS E DROGARIAS S/A    13.534000
# MINÂNCORA & CIA LTDA                                    15.630000
# SALBEGO LABORATÓRIO FARMACÊUTICO LTDA                   17.404000
# HISAMITSU FARMACÊUTICA DO BRASIL LTDA                   18.953333
# DKT DO BRASIL PRODUTOS DE USO PESSOAL LTDA              19.095000
# JARRELL FARMACÊUTICA LTDA EPP                           20.315000
# AVERT LABORATÓRIOS LTDA                                 26.620000
# Name: preco_final_consumidor, dtype: float64

# %%
medicamentos.groupby(medicamentos['laboratorio'])\
    .preco_final_consumidor.mean()\
    .sort_values(ascending=False).head(10)
# Out:
# laboratorio
# NOVARTIS BIOCIENCIAS S.A                                   1.269891e+06
# SPECIALTY PHARMA GOIAS LTDA                                4.294320e+05
# GILEAD SCIENCES FARMACEUTICA DO BRASIL LTDA                3.757024e+05
# PRODUTOS ROCHE QUÍMICOS E FARMACÊUTICOS S.A.               2.998449e+05
# HORIZON THERAPEUTICS BRASIL LTDA.                          2.652993e+05
# AMRYT BRASIL COMERCIO E IMPORTACAO DE MEDICAMENTOS LTDA    2.176555e+05
# PTC FARMACEUTICA DO BRASIL LTDA.                           1.356310e+05
# ALEXION SERVICOS E FARMACEUTICA DO BRASIL LTDA             1.170138e+05
# BIOGEN BRASIL PRODUTOS FARMACEUTICOS LTDA                  1.060474e+05
# VERTEX FARMACEUTICA DO BRASIL LTDA.                        1.006159e+05
# Name: preco_final_consumidor, dtype: float64

# %%
medicamentos.groupby(medicamentos['laboratorio'])\
    .preco_final_consumidor.mean()\
    .sort_values(ascending=True).head(10)\
    .plot(kind='barh', figsize=(10, 6), color="#27A9FF")
# Out:
# <Axes: ylabel='laboratorio'>

# %%
contagem_lab = medicamentos['laboratorio'].value_counts().sort_values(ascending=False).head(10)


ax1 = contagem_lab.plot(
    kind='barh', 
    figsize=(10, 10), 
    color='#2E86C1', 
    title='Quantidade de Produtos por Laboratório',
    ylabel='',
)
ax1
# Out:
# <Axes: title={'center': 'Quantidade de Produtos por Laboratório'}>

# %%
contagem_lab = medicamentos['laboratorio'].value_counts().head(10).sort_values(ascending=True)


ax1 = contagem_lab.plot(
    kind='barh', 
    figsize=(10, 10), 
    color='#2E86C1', 
    title='Quantidade de Produtos por Laboratório',
    ylabel='',
)
ax1

# %%
### Aula 10

# %%
distribuicao_tarja = medicamentos['tarja'].value_counts().sort_values()

ax2 = distribuicao_tarja.plot(
    kind='pie',
    figsize=(7, 7),
    autopct='%1.1f%%',
    startangle=90,
    title='Perfil de Risco (Distribuição de Tarjas)',
    ylabel='' 
)

# %%
# Configurando o tamanho da figura
medicamentos.boxplot(
    column='preco_final_consumidor', 
    by='tipo_produto', 
    grid=False, vert=True,
    figsize=(10, 6),
    patch_artist=True,
    color=dict(boxes='#2E86C1', whiskers='#117A65', medians='#117A65', caps='#117A65'),
)
# Out:
# <Axes: title={'center': 'preco_final_consumidor'}, xlabel='tipo_produto'>

# %%
import matplotlib.pyplot as plt
ax = medicamentos.boxplot(
    column='preco_final_consumidor', 
    by='tipo_produto', 
    figsize=(20, 8), # Aumentei um pouco para garantir leitura
    grid=True, # Grid ajuda a ler log
    color=dict(boxes='#2E86C1', whiskers="#F4F401", medians='#e74c3c', caps='#117A65'),
    showfliers=False,
    patch_artist=True 
)
plt.yscale('log') # Transforma o eixo Y em escala logarítmica

# %%
# 1. ANÁLISE DE NEGÓCIO (Groupby = Tabela Dinâmica)
# Vamos agrupar por Tipo e calcular métricas chaves
analise_precos = medicamentos.groupby('tipo_produto')['preco_final_consumidor'].agg(
    Contagem=('count'),             # Quantos produtos tem?
    Preco_Minimo=('min'),           # Mais barato
    Preco_Medio=('mean'),           # Média (Cuidado!)
    Preco_Mediano=('median'),       # Mediana (A realidade do mercado)
    Preco_Maximo=('max'),           # Mais caro (Outlier)
    Desvio_Padrao=('std')           # Variação
).sort_values('Preco_Mediano', ascending=False)

# 2. FORMATANDO COMO PLANILHA (Styler)
# Isso gera uma visualização HTML idêntica ao Excel com formatação condicional
formatacao = {
    'Preco_Minimo': 'R$ {:,.2f}',
    'Preco_Medio': 'R$ {:,.2f}',
    'Preco_Mediano': 'R$ {:,.2f}',
    'Preco_Maximo': 'R$ {:,.2f}',
    'Desvio_Padrao': 'R$ {:,.2f}'
}

print("=== RELATÓRIO DE PRECIFICAÇÃO POR CATEGORIA ===")
display(
    analise_precos.style
    .format(formatacao)
    # Gradiente de cor para destacar os valores altos (Heatmap)
    .background_gradient(subset=['Preco_Mediano', 'Preco_Maximo'], cmap='Reds')
    .background_gradient(subset=['Contagem'], cmap='Blues')
)
# Out:
# === RELATÓRIO DE PRECIFICAÇÃO POR CATEGORIA ===
# <style type="text/css">
# #T_f1739_row0_col0, #T_f1739_row3_col0 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_f1739_row0_col3, #T_f1739_row0_col4 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_f1739_row1_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_f1739_row1_col3 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_f1739_row1_col4, #T_f1739_row3_col4 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_f1739_row2_col0 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_f1739_row2_col3, #T_f1739_row3_col3, #T_f1739_row4_col3, #T_f1739_row5_col3, #T_f1739_row5_col4, #T_f1739_row6_col3, #T_f1739_row7_col3, #T_f1739_row8_col3, #T_f1739_row8_col4 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_f1739_row2_col4 {
#   background-color: #fff2eb;
#   color: #000000;
# }
# #T_f1739_row4_col0 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_f1739_row4_col4 {
#   background-color: #ffeee7;
#   color: #000000;
# }
# #T_f1739_row5_col0 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_f1739_row6_col0 {
#   background-color: #08458a;
#   color: #f1f1f1;
# }
# #T_f1739_row6_col4 {
#   background-color: #fff2ec;
#   color: #000000;
# }
# #T_f1739_row7_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_f1739_row7_col4 {
#   background-color: #fed9c9;
#   color: #000000;
# }
# #T_f1739_row8_col0 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# </style>
# <table id="T_f1739">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f1739_level0_col0" class="col_heading level0 col0" >Contagem</th>
#       <th id="T_f1739_level0_col1" class="col_heading level0 col1" >Preco_Minimo</th>
#       <th id="T_f1739_level0_col2" class="col_heading level0 col2" >Preco_Medio</th>
#       <th id="T_f1739_level0_col3" class="col_heading level0 col3" >Preco_Mediano</th>
#       <th id="T_f1739_level0_col4" class="col_heading level0 col4" >Preco_Maximo</th>
#       <th id="T_f1739_level0_col5" class="col_heading level0 col5" >Desvio_Padrao</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >tipo_produto</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f1739_level0_row0" class="row_heading level0 row0" >Produto de Terapia Avançada</th>
#       <td id="T_f1739_row0_col0" class="data row0 col0" >44</td>
#       <td id="T_f1739_row0_col1" class="data row0 col1" >R$ 1,321,202.58</td>
#       <td id="T_f1739_row0_col2" class="data row0 col2" >R$ 9,264,894.18</td>
#       <td id="T_f1739_row0_col3" class="data row0 col3" >R$ 10,175,722.18</td>
#       <td id="T_f1739_row0_col4" class="data row0 col4" >R$ 18,932,240.08</td>
#       <td id="T_f1739_row0_col5" class="data row0 col5" >R$ 3,197,410.02</td>
#     </tr>
#     <tr>
#       <th id="T_f1739_level0_row1" class="row_heading level0 row1" >Radiofármaco</th>
#       <td id="T_f1739_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_f1739_row1_col1" class="data row1 col1" >R$ 27,299.63</td>
#       <td id="T_f1739_row1_col2" class="data row1 col2" >R$ 81,873.12</td>
#       <td id="T_f1739_row1_col3" class="data row1 col3" >R$ 81,873.12</td>
#       <td id="T_f1739_row1_col4" class="data row1 col4" >R$ 136,446.61</td>
#       <td id="T_f1739_row1_col5" class="data row1 col5" >R$ 77,178.57</td>
#     </tr>
#     <tr>
#       <th id="T_f1739_level0_row2" class="row_heading level0 row2" >Biológico</th>
#       <td id="T_f1739_row2_col0" class="data row2 col0" >1485</td>
#       <td id="T_f1739_row2_col1" class="data row2 col1" >R$ 12.04</td>
#       <td id="T_f1739_row2_col2" class="data row2 col2" >R$ 9,709.60</td>
#       <td id="T_f1739_row2_col3" class="data row2 col3" >R$ 2,035.30</td>
#       <td id="T_f1739_row2_col4" class="data row2 col4" >R$ 419,418.27</td>
#       <td id="T_f1739_row2_col5" class="data row2 col5" >R$ 30,569.67</td>
#     </tr>
#     <tr>
#       <th id="T_f1739_level0_row3" class="row_heading level0 row3" >Não Informado</th>
#       <td id="T_f1739_row3_col0" class="data row3 col0" >57</td>
#       <td id="T_f1739_row3_col1" class="data row3 col1" >R$ 28.32</td>
#       <td id="T_f1739_row3_col2" class="data row3 col2" >R$ 2,920.13</td>
#       <td id="T_f1739_row3_col3" class="data row3 col3" >R$ 140.23</td>
#       <td id="T_f1739_row3_col4" class="data row3 col4" >R$ 91,698.23</td>
#       <td id="T_f1739_row3_col5" class="data row3 col5" >R$ 12,601.74</td>
#     </tr>
#     <tr>
#       <th id="T_f1739_level0_row4" class="row_heading level0 row4" >Novo</th>
#       <td id="T_f1739_row4_col0" class="data row4 col0" >3813</td>
#       <td id="T_f1739_row4_col1" class="data row4 col1" >R$ 2.38</td>
#       <td id="T_f1739_row4_col2" class="data row4 col2" >R$ 4,419.75</td>
#       <td id="T_f1739_row4_col3" class="data row4 col3" >R$ 116.01</td>
#       <td id="T_f1739_row4_col4" class="data row4 col4" >R$ 789,872.13</td>
#       <td id="T_f1739_row4_col5" class="data row4 col5" >R$ 25,096.35</td>
#     </tr>
#     <tr>
#       <th id="T_f1739_level0_row5" class="row_heading level0 row5" >Específico</th>
#       <td id="T_f1739_row5_col0" class="data row5 col0" >2182</td>
#       <td id="T_f1739_row5_col1" class="data row5 col1" >R$ 1.32</td>
#       <td id="T_f1739_row5_col2" class="data row5 col2" >R$ 341.28</td>
#       <td id="T_f1739_row5_col3" class="data row5 col3" >R$ 94.77</td>
#       <td id="T_f1739_row5_col4" class="data row5 col4" >R$ 8,301.11</td>
#       <td id="T_f1739_row5_col5" class="data row5 col5" >R$ 845.19</td>
#     </tr>
#     <tr>
#       <th id="T_f1739_level0_row6" class="row_heading level0 row6" >Similar</th>
#       <td id="T_f1739_row6_col0" class="data row6 col0" >9018</td>
#       <td id="T_f1739_row6_col1" class="data row6 col1" >R$ 0.90</td>
#       <td id="T_f1739_row6_col2" class="data row6 col2" >R$ 971.65</td>
#       <td id="T_f1739_row6_col3" class="data row6 col3" >R$ 93.12</td>
#       <td id="T_f1739_row6_col4" class="data row6 col4" >R$ 358,586.98</td>
#       <td id="T_f1739_row6_col5" class="data row6 col5" >R$ 6,186.96</td>
#     </tr>
#     <tr>
#       <th id="T_f1739_level0_row7" class="row_heading level0 row7" >Genérico</th>
#       <td id="T_f1739_row7_col0" class="data row7 col0" >9816</td>
#       <td id="T_f1739_row7_col1" class="data row7 col1" >R$ 0.55</td>
#       <td id="T_f1739_row7_col2" class="data row7 col2" >R$ 1,092.33</td>
#       <td id="T_f1739_row7_col3" class="data row7 col3" >R$ 76.75</td>
#       <td id="T_f1739_row7_col4" class="data row7 col4" >R$ 2,861,191.01</td>
#       <td id="T_f1739_row7_col5" class="data row7 col5" >R$ 30,187.95</td>
#     </tr>
#     <tr>
#       <th id="T_f1739_level0_row8" class="row_heading level0 row8" >Fitoterápico</th>
#       <td id="T_f1739_row8_col0" class="data row8 col0" >358</td>
#       <td id="T_f1739_row8_col1" class="data row8 col1" >R$ 7.62</td>
#       <td id="T_f1739_row8_col2" class="data row8 col2" >R$ 99.72</td>
#       <td id="T_f1739_row8_col3" class="data row8 col3" >R$ 52.48</td>
#       <td id="T_f1739_row8_col4" class="data row8 col4" >R$ 2,056.84</td>
#       <td id="T_f1739_row8_col5" class="data row8 col5" >R$ 208.49</td>
#     </tr>
#   </tbody>
# </table>
