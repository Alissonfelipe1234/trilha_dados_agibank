# %%
from langchain_chroma import Chroma
from langchain_huggingface import HuggingFaceEmbeddings

PASTA_BANCO = "./banco_vetorial"
embedding_model = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")

vector_store = Chroma(
    persist_directory=PASTA_BANCO,
    embedding_function=embedding_model
)

# %%
pergunta = "Qual o valor do VR"

print(f"🔍 Buscando no banco por: '{pergunta}'")
docs = vector_store.similarity_search(pergunta, k=3)

print(f"📄 Documentos encontrados: {len(docs)}")
print("-" * 40)

for i, doc in enumerate(docs):
    print(f"--- Resultado {i+1} (Fonte: {doc.metadata.get('source', '?')}) ---")
    print(doc.page_content)
    print("-" * 40)
# Out:
# 🔍 Buscando no banco por: 'Qual o valor do VR'
# 📄 Documentos encontrados: 1
# ----------------------------------------
# --- Resultado 1 (Fonte: ./beneficios.pdf) ---
# POLÍTICA  DE  BENEFÍCIOS  -  AGIBANK
# Vale  Refeição  (VR)  O  valor  diário  é  de  R$  45,00.  Em  caso  de  férias,  o  benefício  não  é
# depositado.
#
# O
#
# cartão
#
# é
#
# da
#
# bandeira
#
# "Flash".
#
# Plano  de  Saúde  A  empresa  cobre  100%  do  plano  "Amil  400"  para  o  funcionário.  Para
# dependentes
#
# (filhos
#
# e
#
# cônjuges),
#
# a
#
# empresa
#
# paga
#
# 50%
#
# e
#
# o
#
# funcionário
#
# paga
#
# os
#
# outros
#
# 50%
#
# descontados
#
# em
#
# folha.
#
# Day  Off  O  funcionário  tem  direito  a  uma  folga  no  mês  do  seu  aniversário.  Essa  folga  deve
# ser
#
# agendada
#
# com
#
# 15
#
# dias
#
# de
#
# antecedência
#
# com
#
# o
#
# gestor
#
# imediato.
#
# Não
#
# é
#
# permitido
#
# vender
#
# essa
#
# folga.
# ----------------------------------------
